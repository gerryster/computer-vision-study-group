# %% [markdown]
# # A Quest for Determanism in Matplotlib Jupyter Output
#
# No success so far. https://stackoverflow.com/questions/46039835/control-class-and-id-attributes-of-matplotlib-svg-figures seemed somewhat promising, however the API call it suggested is not one used with images.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from numpy import array

img = array([[0, 255], [255, 0]])
plt.imshow(img)
